# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanket-010s/ML/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# creats the array of range (a, b-1)
arr = np.arange(0, 11)
# arr[5]

slice_arr =arr[0:5]
slice_arr[:] = 99
# slice_arr
arr
# Out:
# array([99, 99, 99, 99, 99,  5,  6,  7,  8,  9, 10])

# %%
import numpy as np

arr_2d = np.array(([20,20,30],[10,20,30],[40,50,60]))

arr_2d[0]
# Out:
# array([20, 20, 30])
